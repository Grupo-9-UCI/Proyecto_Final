# %% [markdown]
# ## EDA - ETL

# %%
# Lo primero es Importar las librerias que utilizaremos en el proceso de Extraccion, Transformacion y carga de datos (ETL).
import pandas as pd
import numpy as np

# %%
#Se realizara la carga de archivos valores separados por comas (CSV)
df_inputevents_cv= pd.read_csv('INPUTEVENTS_CV.csv')
df_inputevents_mv= pd.read_csv('INPUTEVENTS_MV.csv')
df_labevents= pd.read_csv('LABEVENTS.csv')
df_microbiologyevents = pd.read_csv('MICROBIOLOGYEVENTS.csv')
df_procedureevents_mv = pd.read_csv('PROCEDUREEVENTS_MV.csv')
df_procedures_icd = pd.read_csv('PROCEDURES_ICD.csv')
df_icustays = pd.read_csv('ICUSTAYS.csv')
df_outputevents = pd.read_csv('OUTPUTEVENTS.csv')
# Out:
# C:\Users\Roman Samuel Bracho\AppData\Local\Temp\ipykernel_13356\2962143580.py:2: DtypeWarning: Columns (17,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_inputevents_cv= pd.read_csv('INPUTEVENTS_CV.csv')

# %% [markdown]
# Se eliminan columnas inncesarias de los datasets

# %% [markdown]
# INPUTEVENTS_CV = se eliminan las columnas rate, rateuom, stopped, newbottle, originalamount, originalrate y originalsite. Los supuestos valores nulos son celdas en blanco se dejan como estan ya que no son un obstaculo para el analisis

# %%
# calcular el porcentaje de valores nulos para cada columna
null_percentages = df_inputevents_cv.isnull().sum() / len(df_inputevents_cv)

# imprimir las columnas que tienen más del 50% de valores nulos
print(null_percentages[null_percentages > 0.5])
# Out:
# rate               0.728096
# rateuom            0.725624
# stopped            0.976723
# newbottle          0.985000
# originalrate       0.669215
# originalrateuom    0.669100
# originalsite       0.999828
# dtype: float64

# %%
df_inputevents_cv
# Out:
#          row_id  subject_id  hadm_id  icustay_id            charttime  itemid  \
# 0          1184       10114   167957      234989  2171-11-03 15:00:00   30056
# 1          1185       10114   167957      234989  2171-11-03 20:00:00   30056
# 2          1186       10114   167957      234989  2171-11-03 23:00:00   30056
# 3          1187       10114   167957      234989  2171-11-04 02:00:00   30056
# 4          1188       10114   167957      234989  2171-11-04 05:00:00   30056
# ...         ...         ...      ...         ...                  ...     ...
# 34794  17489341       10112   188574      224063  2148-01-16 10:00:00   40864
# 34795  17489342       10112   188574      224063  2148-01-16 11:00:00   40864
# 34796  17489343       10112   188574      224063  2148-01-16 12:00:00   40864
# 34797  17489344       10112   188574      224063  2148-01-16 13:00:00   40864
# 34798  17489345       10112   188574      224063  2148-01-16 14:00:00   40864
#
# ...

# %%
df_inputevents_cv.drop(columns=['rate', 'rateuom', 'stopped', 'newbottle', 'originalamount', 'originalrate', 'originalsite', 'originalrateuom'], inplace=True)

# %%
#se crea nuevo df para con los cambios para nuestro trabajo sin afectar al original
df_inputevents_cv.to_csv("df_inputevents_cv.csv", index=False)

# %% [markdown]
# INPUTEVENTS_MV = se eliminan las columnas que no seran necesarios para nuestro trabajo, comments_editedby, comments_canceledby, comments_date

# %%
# calcular el porcentaje de valores nulos para cada columna
null_percentages = df_inputevents_mv.isnull().sum() / len(df_inputevents_mv)

# imprimir las columnas que tienen más del 50% de valores nulos
print(null_percentages[null_percentages > 0.5])
# Out:
# comments_editedby      0.904341
# comments_canceledby    0.963778
# comments_date          0.868119
# dtype: float64

# %%
df_inputevents_mv
# Out:
#         row_id  subject_id  hadm_id  icustay_id            starttime  \
# 0       118897       42367   139932      250305  2147-10-29 16:45:00
# 1       118898       42367   139932      250305  2147-10-20 13:17:00
# 2       118899       42367   139932      250305  2147-10-29 03:23:00
# 3       118900       42367   139932      250305  2147-10-22 22:00:00
# 4       118901       42367   139932      250305  2147-10-16 06:21:00
# ...        ...         ...      ...         ...                  ...
# 13219  3349714       41976   145024      291067  2202-05-02 13:50:00
# 13220  3349715       41976   145024      291067  2202-05-02 13:50:00
# 13221  3349716       41976   145024      291067  2202-05-02 01:00:00
# 13222  3349717       41976   145024      291067  2202-05-02 01:00:00
# 13223  3349718       41976   145024      291067  2202-05-02 01:00:00
#
#                    endtime  itemid       amount amountuom        rate  ...  \
# ...

# %%
df_inputevents_mv.drop(columns=['comments_editedby', 'comments_canceledby', 'comments_date'], inplace=True)

# %%
#se crea nuevo df para con los cambios para nuestro trabajo sin afectar al original
df_inputevents_mv.to_csv("df_inputevents_mv.csv", index=False)

# %% [markdown]
# LABEVENTS = se eliminan las columnas que no seran necesarios para nuestro trabajo: flag

# %%
# calcular el porcentaje de valores nulos para cada columna
null_percentages = df_labevents.isnull().sum() / len(df_labevents)

# imprimir las columnas que tienen más del 50% de valores nulos
print(null_percentages[null_percentages > 0.5])
# Out:
# flag    0.609104
# dtype: float64

# %%
df_labevents
# Out:
#          row_id  subject_id   hadm_id  itemid            charttime value  \
# 0       6244563       10006       NaN   50868  2164-09-24 20:21:00    19
# 1       6244564       10006       NaN   50882  2164-09-24 20:21:00    27
# 2       6244565       10006       NaN   50893  2164-09-24 20:21:00  10.0
# 3       6244566       10006       NaN   50902  2164-09-24 20:21:00    97
# 4       6244567       10006       NaN   50912  2164-09-24 20:21:00   7.0
# ...         ...         ...       ...     ...                  ...   ...
# 76069  20452679       44228  103379.0   51250  2170-12-24 04:09:00    88
# 76070  20452680       44228  103379.0   51265  2170-12-24 04:09:00   595
# 76071  20452681       44228  103379.0   51277  2170-12-24 04:09:00  14.5
# 76072  20452682       44228  103379.0   51279  2170-12-24 04:09:00  2.76
# 76073  20452683       44228  103379.0   51301  2170-12-24 04:09:00  16.9
#
#        valuenum valueuom      flag
# 0         19.00    mEq/L       NaN
# ...

# %%
df_labevents.drop(columns=['flag'], inplace=True)

# %%
#se crea nuevo df para con los cambios para nuestro trabajo sin afectar al original
df_labevents.to_csv("df_labevents.csv", index=False)

# %% [markdown]
# MICROBIOLOGYEVENTS = se eliminan las columnas que no seran necesarios para nuestro trabajo: ab_itemid, ab_name, dilution_text, dilution_comparison, dilution_value, interpretation

# %%
# calcular el porcentaje de valores nulos para cada columna
null_percentages = df_microbiologyevents.isnull().sum() / len(df_microbiologyevents)

# imprimir las columnas que tienen más del 50% de valores nulos
print(null_percentages[null_percentages > 0.5])
# Out:
# ab_itemid              0.515227
# ab_name                0.515227
# dilution_text          0.531203
# dilution_comparison    0.531702
# dilution_value         0.531702
# interpretation         0.515227
# dtype: float64

# %%
df_microbiologyevents
# Out:
#       row_id  subject_id  hadm_id            chartdate            charttime  \
# 0     134694       10006   142345  2164-10-23 00:00:00  2164-10-23 15:30:00
# 1     134695       10006   142345  2164-10-23 00:00:00  2164-10-23 15:30:00
# 2     134696       10006   142345  2164-10-23 00:00:00  2164-10-23 15:30:00
# 3     134697       10006   142345  2164-10-23 00:00:00  2164-10-23 15:30:00
# 4     134698       10006   142345  2164-10-23 00:00:00  2164-10-23 15:30:00
# ...      ...         ...      ...                  ...                  ...
# 1998  439860       44228   103379  2170-12-17 00:00:00  2170-12-17 12:33:00
# 1999  439861       44228   103379  2170-12-17 00:00:00  2170-12-17 15:42:00
# 2000  439862       44228   103379  2170-12-17 00:00:00  2170-12-17 18:23:00
# 2001  439863       44228   103379  2170-12-18 00:00:00  2170-12-18 16:49:00
# 2002  439864       44228   103379  2170-12-24 00:00:00  2170-12-24 14:44:00
#
#       spec_itemid spec_type_desc  org_itemid  \
# ...

# %%
df_microbiologyevents.drop(columns=['ab_itemid','ab_name', 'dilution_text', 'dilution_comparison', 'dilution_value', 'interpretation'  ], inplace=True)

# %%
#se crea nuevo df para con los cambios para nuestro trabajo sin afectar al original
df_microbiologyevents.to_csv("df_microbiologyevents.csv", index=False)

# %% [markdown]
# PROCEDUREEVENTS_MV = se eliminan las columnas que no seran necesarios para nuestro trabajo: location, locationcategory, secondaryordercategoryname, comments_editedby, comments_canceledby, comments_date

# %%
# calcular el porcentaje de valores nulos para cada columna
null_percentages = df_procedureevents_mv.isnull().sum() / len(df_procedureevents_mv)

# imprimir las columnas que tienen más del 50% de valores nulos
print(null_percentages[null_percentages > 0.5])
# Out:
# location                      0.843293
# locationcategory              0.843293
# secondaryordercategoryname    1.000000
# comments_editedby             0.994688
# comments_canceledby           0.974768
# comments_date                 0.969456
# dtype: float64

# %%
df_procedureevents_mv
# Out:
#      row_id  subject_id  hadm_id  icustay_id            starttime  \
# 0      8641       42367   139932      250305  2147-10-03 16:40:00
# 1      8642       42367   139932      250305  2147-10-03 16:41:00
# 2      8643       42367   139932      250305  2147-10-03 17:10:00
# 3      8644       42367   139932      250305  2147-10-04 11:00:00
# 4      8645       42367   139932      250305  2147-10-04 14:16:00
# ..      ...         ...      ...         ...                  ...
# 748  226312       41976   151798      280943  2202-02-15 22:29:00
# 749  226313       41976   151798      280943  2202-02-15 22:30:00
# 750  226314       41976   151798      280943  2202-02-15 22:30:00
# 751  226315       41976   151798      280943  2202-02-16 11:21:00
# 752  238542       41976   145024      291067  2202-05-02 00:00:00
#
#                  endtime  itemid  value valueuom         location  ...  \
# 0    2147-10-06 20:00:00  224263   4520      min   Right Femoral.  ...
# ...

# %%
df_procedureevents_mv.drop(columns=['location', 'locationcategory', 'secondaryordercategoryname', 'comments_editedby', 'comments_canceledby', 'comments_date' ], inplace=True)

# %%
#se crea nuevo df para con los cambios para nuestro trabajo sin afectar al original
df_procedureevents_mv.to_csv("df_procedureevents.csv", index=False)

# %% [markdown]
# PROCEDURES_ICD = se eliminan las columnas que no seran necesarios para nuestro trabajo: (NO TIENE COLUMNAS CON MAS DEL 50% NULO)

# %%
# calcular el porcentaje de valores nulos para cada columna
null_percentages = df_procedures_icd.isnull().sum() / len(df_procedures_icd)

# imprimir las columnas que tienen más del 50% de valores nulos
print(null_percentages[null_percentages > 0.5])
# Out:
# Series([], dtype: float64)

# %%
df_procedures_icd
# Out:
#      row_id  subject_id  hadm_id  seq_num  icd9_code
# 0      3994       10114   167957        1       3605
# 1      3995       10114   167957        2       3722
# 2      3996       10114   167957        3       8856
# 3      3997       10114   167957        4       9920
# 4      3998       10114   167957        5       9671
# ..      ...         ...      ...      ...        ...
# 501  230170       41976   179418        2       3893
# 502  235193       41976   155297        1       3893
# 503  235194       41976   155297        2        966
# 504  238588       41976   125013        1       3893
# 505  239961       41976   151798        1        966
#
# [506 rows x 5 columns]

# %%
#se crea nuevo df para con los cambios para nuestro trabajo sin afectar al original
df_procedures_icd.to_csv("df_procedures_icd.csv", index=False)

# %% [markdown]
# ICUSTAYS = se eliminan las columnas que no seran necesarios para nuestro trabajo: (NO TIENE COLUMNAS CON MAS DEL 50% NULO)

# %%
# calcular el porcentaje de valores nulos para cada columna
null_percentages = df_icustays.isnull().sum() / len(df_icustays)

# imprimir las columnas que tienen más del 50% de valores nulos
print(null_percentages[null_percentages > 0.5])
# Out:
# Series([], dtype: float64)

# %%
df_icustays
# Out:
#      row_id  subject_id  hadm_id  icustay_id    dbsource first_careunit  \
# 0     12742       10006   142345      206504     carevue           MICU
# 1     12747       10011   105331      232110     carevue           MICU
# 2     12749       10013   165520      264446     carevue           MICU
# 3     12754       10017   199207      204881     carevue            CCU
# 4     12755       10019   177759      228977     carevue           MICU
# ..      ...         ...      ...         ...         ...            ...
# 131   42676       44083   198330      286428  metavision            CCU
# 132   42691       44154   174245      217724  metavision           MICU
# 133   42709       44212   163189      239396  metavision           MICU
# 134   42712       44222   192189      238186  metavision            CCU
# 135   42714       44228   103379      217992  metavision           SICU
#
#     last_careunit  first_wardid  last_wardid               intime  \
# ...

# %%
#se crea nuevo df para con los cambios para nuestro trabajo sin afectar al original
df_icustays.to_csv("df_icustays.csv", index=False)

# %% [markdown]
# OUTPUTEVENTS = se eliminan las columnas que no seran necesarios para nuestro trabajo: stopped, newbottle, iserror

# %%
# calcular el porcentaje de valores nulos para cada columna
null_percentages = df_outputevents.isnull().sum() / len(df_outputevents)

# imprimir las columnas que tienen más del 50% de valores nulos
print(null_percentages[null_percentages > 0.5])
# Out:
# stopped      1.0
# newbottle    1.0
# iserror      1.0
# dtype: float64

# %%
df_outputevents
# Out:
#         row_id  subject_id  hadm_id  icustay_id            charttime  itemid  \
# 0         6540       10114   167957    234989.0  2171-10-30 20:00:00   40055
# 1         6541       10114   167957    234989.0  2171-10-30 21:00:00   40055
# 2         6542       10114   167957    234989.0  2171-10-30 23:00:00   40055
# 3         6543       10114   167957    234989.0  2171-10-31 00:00:00   40055
# 4         6544       10114   167957    234989.0  2171-10-31 02:00:00   40055
# ...        ...         ...      ...         ...                  ...     ...
# 11315  4226038       41976   145024    291067.0  2202-05-02 12:00:00  226559
# 11316  4226039       41976   145024    291067.0  2202-05-02 16:00:00  226559
# 11317  4226040       41976   145024    291067.0  2202-05-02 19:00:00  226559
# 11318  4226041       41976   145024    291067.0  2202-05-02 20:00:00  226559
# 11319  4226042       41976   145024    291067.0  2202-05-01 23:30:00  226582
#
# ...

# %%
df_outputevents.drop(columns=['stopped', 'newbottle', 'iserror'], inplace=True)

# %%
#se crea nuevo df para con los cambios para nuestro trabajo sin afectar al original
df_outputevents.to_csv("df_outputevents.csv", index=False)
